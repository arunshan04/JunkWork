# %%
print(locals(),globals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'import os\nimport io\nimport asyncio\nfrom functools import partial\nfrom typing import AsyncIterator\nimport time\n\nLINE_BUFFER = 1\n\nimport logging\nimport time\n\nlogger_format = \'%(asctime)s:%(threadName)s:%(message)s\'\nlogging.basicConfig(format=logger_format, level=logging.INFO, datefmt="%H:%M:%S")', "asyncio.run(main(['/var/log/syslog','/var/log/auth.log','/tmp/1.txt']))", 'async def tail( filename, last_lines = 10, non_exist_max_secs = 10.0, fp_poll_secs = 0.125):\n    """Continuously tail a file pointer yielding one line at a time."""\n\n    async def wait_exists():\n        """Wait for a file to exist, the return statement reflects\n        whether or not the file existed when the timeout limits were rea
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-e5c8857ecc6a> in <module>
# ----> 1 asyncio.run(main(['/var/log/syslog','/var/log/auth.log','/tmp/1.txt']))
#
# /opt/anaconda3/lib/python3.7/asyncio/runners.py in run(main, debug)
#      32     if events._get_running_loop() is not None:
#      33         raise RuntimeError(
# ---> 34             "asyncio.run() cannot be called from a running event loop")
#      35
#      36     if not coroutines.iscoroutine(main):
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
